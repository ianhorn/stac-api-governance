# %%
import json

# %%
json_file = r'C:\Users\Ian.Horn\Documents\stac-repos\items\orthos-phase1\N011E284_2012_1FT_cog.tif.json'

# %%
with open(json_file, 'r+') as f:
    data = json.load(f)

print(json.dumps(data, indent=2))

# %%
data['assets']

# %%
assets = data['assets']

if 'asset' in assets:  
    data['assets'] = {
        'data': assets.pop('asset'),
        'thumbnail': assets['thumbnail']
    }

# %%
data['assets']

# %%
links = data['links']
links.clear()
data['links']

# %%
data['assets']

# %%
data['assets']['thumbnail']

# %%
# if data['id'].endswith('.copc.laz'):
